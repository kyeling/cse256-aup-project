# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('Raw_Disallows.csv')

# %%
label_to_category = {
    # Violations of Law
    'Violate law': 'Violations of Law',
    'Illegal activity': 'Violations of Law',
    'Breach Law': 'Violations of Law',
    'Unlawful Use': 'Violations of Law',
    'Unlawful/Fraudulent': 'Violations of Law',
    'Copyright Infringement': 'Violations of Law',
    'Lawful Use': 'Violations of Law',
    'Unlawful Content': 'Violations of Law',
    'Breaching Law': 'Violations of Law',

    # Spam and Unsolicited Content
    'Spam': 'Spam and Unsolicited Content',
    'Spamming': 'Spam and Unsolicited Content',
    'Unsolicited Advertising': 'Spam and Unsolicited Content',
    'Spam email': 'Spam and Unsolicited Content',
    'Unsolicited Texts': 'Spam and Unsolicited Content',
    'Spam Texts': 'Spam and Unsolicited Content',
    'Unsolicited Ad': 'Spam and Unsolicited Content',
    'Unsolicited mass email': 'Spam and Unsolicited Content',
    'Prohibited Content': 'Spam and Unsolicited Content',
    'Prohibited Use': 'Spam and Unsolicited Content',
    'Mail Bombing': 'Spam and Unsolicited Content',
    'Unsolicited Commercial Email': 'Spam and Unsolicited Content',

    # Security and Privacy Violations
    'Unauthorized Access': 'Security and Privacy Violations',
    'Unauthorized Use': 'Security and Privacy Violations',
    'Unauthorized Sharing': 'Security and Privacy Violations',
    'Unauthorized Distribution': 'Security and Privacy Violations',
    'Unauthorized Modification': 'Security and Privacy Violations',
    'Unauthorized Disclosure': 'Security and Privacy Violations',
    'Unauthorized Disruption': 'Security and Privacy Violations',
    'Unauthorized Monitoring': 'Security and Privacy Violations',
    'Security breach': 'Security and Privacy Violations',
    'Privacy invasion': 'Security and Privacy Violations',
    'Identity Theft': 'Security and Privacy Violations',
    'Malicious Software': 'Security and Privacy Violations',
    'Malware upload': 'Security and Privacy Violations',
    'Malicious Attack': 'Security and Privacy Violations',
    'Security Abuse': 'Security and Privacy Violations',
    'Security Bypass': 'Security and Privacy Violations',
    'Security Risk': 'Security and Privacy Violations',
    'System disruption': 'Security and Privacy Violations',
    'Code tampering': 'Security and Privacy Violations',
    'Malicious Code': 'Security and Privacy Violations',
    'Privacy violation': 'Security and Privacy Violations',
    'Unauthorized IP Use': 'Security and Privacy Violations',
    'Violate Policy': 'Security and Privacy Violations',
    'Security Interference': 'Security and Privacy Violations',

    # Harassment and Bullying
    'Harassment/Bullying': 'Harassment and Bullying',
    'Bully': 'Harassment and Bullying',
    'Humiliate': 'Harassment and Bullying',
    'Insult, intimidate': 'Harassment and Bullying',
    'Harassment': 'Harassment and Bullying',
    'Threatening': 'Harassment and Bullying',
    'Discrimination': 'Harassment and Bullying',

    # Inappropriate and Offensive Content
    'Offensive Content': 'Inappropriate and Offensive Content',
    'Offensive material': 'Inappropriate and Offensive Content',
    'Inappropriate': 'Inappropriate and Offensive Content',
    'Inappropriate Linking': 'Inappropriate and Offensive Content',
    'Inappropriate Use': 'Inappropriate and Offensive Content',
    'Obscene': 'Inappropriate and Offensive Content',
    'Libelous': 'Inappropriate and Offensive Content',
    'Defamatory': 'Inappropriate and Offensive Content',
    'Hateful': 'Inappropriate and Offensive Content',
    'Harmful to Minors': 'Inappropriate and Offensive Content',
    'Harassing Content': 'Inappropriate and Offensive Content',
    'Hate Speech': 'Inappropriate and Offensive Content',
    'Pornography': 'Inappropriate and Offensive Content',
    'Sexual Services': 'Inappropriate and Offensive Content',
    'Sexual Establishments': 'Inappropriate and Offensive Content',

    # High-Risk and Harmful Activities
    'High Risk Use': 'High-Risk and Harmful Activities',
    'Harm minors': 'High-Risk and Harmful Activities',
    'Harm Minors': 'High-Risk and Harmful Activities',
    'Harmful Activity': 'High-Risk and Harmful Activities',
    'Harmful programs': 'High-Risk and Harmful Activities',
    'Harmful Content': 'High-Risk and Harmful Activities',
    'Harmful activities': 'High-Risk and Harmful Activities',
    'Harm': 'High-Risk and Harmful Activities',
    'Violence': 'High-Risk and Harmful Activities',
    'Violence Promotion': 'High-Risk and Harmful Activities',
    'Violent Promotion': 'High-Risk and Harmful Activities',
    'Violence incitement': 'High-Risk and Harmful Activities',
    'Violence Threats': 'High-Risk and Harmful Activities',

    # Fraud and Misuse
    'Misuse': 'Fraud and Misuse',
    'Misuse of resources': 'Fraud and Misuse',
    'Misuse data': 'Fraud and Misuse',
    'Misuse Services': 'Fraud and Misuse',
    'Misrepresentation': 'Fraud and Misuse',
    'Misleading activity': 'Fraud and Misuse',
    'Misleading': 'Fraud and Misuse',
    'Misleading Information': 'Fraud and Misuse',
    'Misleading conduct': 'Fraud and Misuse',
    'Fraudulent Use': 'Fraud and Misuse',
    'Fraudulent Conduct': 'Fraud and Misuse',
    'Unlawful/Fraud': 'Fraud and Misuse',

    # Network and System Interference
    'Overloading': 'Network and System Interference',
    'Interference': 'Network and System Interference',
    'Disturb Operation': 'Network and System Interference',
    'Compromise Security': 'Network and System Interference',
    'Circumvent Authentication': 'Network and System Interference',
    'Compromising': 'Network and System Interference',
    'Bypassing': 'Network and System Interference',
    'Fail to Update': 'Network and System Interference',
    'Disturbance': 'Network and System Interference',
    'Network Security': 'Network and System Interference',
    'Network Interference': 'Network and System Interference',
    'System Interference': 'Network and System Interference',
    'Disruption': 'Network and System Interference',
    'Spoofing': 'Network and System Interference',
    'Reverse Engineering': 'Network and System Interference',
    'Disruptive activity': 'Network and System Interference',
    'Performance disruption': 'Network and System Interference',
    'Quality disruption': 'Network and System Interference',
    'Service Interruptions': 'Network and System Interference',
    'Service disruption': 'Network and System Interference',

    # Intellectual Property Infringement
    'Copyright Infringement': 'Intellectual Property Infringement',
    'Infringing': 'Intellectual Property Infringement',
    'Infringing IP': 'Intellectual Property Infringement',
    'Infringe': 'Intellectual Property Infringement',
    'Intellectual property': 'Intellectual Property Infringement',
    'IP infringement': 'Intellectual Property Infringement',
    'Infringing Material': 'Intellectual Property Infringement',
    'Trademark Infringement': 'Intellectual Property Infringement',
    'Copyright breach': 'Intellectual Property Infringement',
    'Infringing Content': 'Intellectual Property Infringement',

    # Other Violations
    'Non-Compliant': 'Other Violations',
    'Non-Responsive': 'Other Violations',
    'Non-Delivery': 'Other Violations',
    'Non-Commercial Use': 'Other Violations',
    'Non-Consensual Sex': 'Other Violations',
    'Non-Compliance': 'Other Violations',
    'Non-Permitted Server': 'Other Violations',
    'Not following instructions': 'Other Violations',
    'Offense': 'Other Violations',
    'Violation': 'Other Violations',
    'Violate rights': 'Other Violations',
    'Rights Violation': 'Other Violations',
    'Rights Interference': 'Other Violations'
}


df['New_Label'] = df['Label'].map(label_to_category)

# Check for any labels that were not included in the label_to_category dictionary
# assign a new_label value of NaN
missing_labels = df['Label'][df['New_Label'].isnull()].unique()

# %%
df
# Out:
#               TextFile                   Disallowed Action  \
# 0      199-current.txt              Violate applicable law
# 1     6215-current.txt                             copying
# 2     6215-current.txt            non-automated “scraping”
# 3     6215-current.txt                    automated system
# 4     6215-current.txt                   transmitting spam
# ...                ...                                 ...
# 1170      163-2023.txt                   Offensive Content
# 1171      163-2023.txt                     Harmful Content
# 1172       48-2023.txt         Illegal or damaging actions
# 1173       48-2023.txt       Compromise of network systems
# 1174       48-2023.txt  Conducting non-business activities
#
#                       Label                     New_Label
# 0               Violate law             Violations of Law
# 1              Distributing                           NaN
# 2                  Scraping                           NaN
# ...

# %%
# Step 1: Group by "TextFile" and find the most frequent "Label" within each group
grouped_by_textfile = df.groupby('TextFile')['Label'].apply(lambda x: x.value_counts().idxmax())

# Step 2: Group by "Label" and find the top 10 labels that occur the most
top_10_labels = df.groupby('New_Label').size().nlargest(10)

# Print the results
print("\nTop 10 disallows that occur the most:")
print(top_10_labels)
# Out:
# Top 10 disallows that occur the most:
# New_Label
# Security and Privacy Violations        124
# Fraud and Misuse                        65
# Spam and Unsolicited Content            53
# High-Risk and Harmful Activities        48
# Inappropriate and Offensive Content     33
# Network and System Interference         26
# Violations of Law                       24
# Intellectual Property Infringement      21
# Harassment and Bullying                 20
# Other Violations                        15
# dtype: int64
